# %% [markdown]
# ### Preparing the data
# In this notebook, we demonstrate how to prepare the Mouse Smart-seq dataset, which is a single-cell dataset was released as part of a transcriptomic cell types study in [Tasic et al., 2018](https://portal.brain-map.org/atlases-and-data/rnaseq/mouse-v1-and-alm-smart-seq). The dataset includes RNA sequencing of neurons from the anterolateral motor cortex (ALM) and primary visual cortex (VISp) regions of adult mice using Smart-seq (SSv4) platform.

# %%
import os, sys
import scipy.io as sio
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import modules
module_path = '/Users/yeganeh.marghi/github/MMIDAS/'
sys.path.insert(0, module_path)
from utils.tree_based_analysis import get_merged_types
from utils.analysis_cells_tree import HTree
from utils.config import load_config
from utils.data_tools import normalize_cellxgene

# %% [markdown]
# Download ```zip``` files and place them the data folder. There should be a ```config.toml```,  which is a global configuration file containing following paths:
#
#
# * ```package_dir='xxx'```
# * ```data_path='xxx'```

# %%
paths = load_config(config_file='config.toml')
data_path = paths['package_dir'] / paths['data_path']

# %%
# Load the mouse Smart-seq VISp data
data_VISp_exon = data_path / 'mouse_VISp_2018-06-14_exon-matrix.csv'
anno_VISp = data_path / 'mouse_VISp_2018-06-14_samples-columns.csv'
df_vis_exon = pd.read_csv(data_VISp_exon)
df_vis_anno = pd.read_csv(anno_VISp, encoding='unicode_escape')

# Load the mouse Smart-seq ALM data
data_ALM_exon = data_path / 'mouse_ALM_2018-06-14_exon-matrix.csv'
anno_ALM = data_path / 'mouse_ALM_2018-06-14_samples-columns.csv'
df_alm_exon = pd.read_csv(data_ALM_exon)
df_alm_anno = pd.read_csv(anno_ALM, encoding='unicode_escape')

print(f'Total number of cells in VISp and ALM: {len(df_vis_anno)}, {len(df_alm_anno)}')
# Out:
# Total number of cellsin VISp and ALM: 15413,  10068

# %%
# Get the neuronal cells across brain regions
vis_neuron = df_vis_anno['class'].isin(['GABAergic', 'Glutamatergic'])
alm_neuron = df_alm_anno['class'].isin(['GABAergic', 'Glutamatergic'])
vis_counts = df_vis_exon.values[:, 1:][:, vis_neuron].T
alm_counts = df_alm_exon.values[:, 1:][:, alm_neuron].T

df_anno = pd.concat([df_vis_anno[vis_neuron], df_alm_anno[alm_neuron]], ignore_index=True)
total_count = np.concatenate((vis_counts, alm_counts), axis=0)

# Normalized counts values using LogCPM
logCPM = np.log1p(normalize_cellxgene(total_count) * 1e6)

print(np.sum(logCPM, axis=1))
# Out:
# [30890.15859407 34090.13980254 35085.63428565 ... 34077.15380524
#  31090.81791427 35629.482184  ]

# %%
# list of all genes in the dataset
ref_gene_file = data_path / 'mouse_ALM_2018-06-14_genes-rows.csv'

# selected genes for mouse Smart-seq data analysis
slc_gene_file = data_path / 'genes_SS_VISp_ALM.csv'

ref_genes_df = pd.read_csv(ref_gene_file)
slc_gene_df = pd.read_csv(slc_gene_file)

print(ref_genes_df[41530:41550])
print('-'*100)
print(f'Total number of genes: {len(ref_genes_df)}, Number of selected genes: {len(slc_gene_df)}')
# Out:
#       gene_symbol    gene_id chromosome  gene_entrez_id  \
# 41530      Sssca1  500741647         19           56390
# 41531         Sst  500737291         16           20604
# 41532       Sstr1  500729687         12           20605
# 41533       Sstr2  500728684         11           20606
# 41534       Sstr3  500736064         15           20607
# 41535       Sstr4  500704969          2           20608
# 41536       Sstr5  500738797         17           20609
# 41537       Ssty1  500745186          Y           20611
# 41538       Ssty2  500745340          Y           70009
# 41539        Ssu2  500714992          6          243612
# 41540       Ssu72  500710656          4           68991
# 41541      Ssx2ip  500707937          3           99167
# 41542        Ssx9  500742933          X          382206
# 41543       Ssxa1  500743112          X          385338
# 41544       Ssxb1  500742924          X           67985
# 41545      Ssxb10  500742922          X          385312
# 41546       Ssxb2  500742925          X          387132
# 41547       Ssxb3  500742928          X          278174
# 41548       Ssxb5  500742934          X          387586
# 41549       Ssxb6  500742927          X          668976
#
#                                                gene_name
# 41530  Sjogren''s syndrome/scleroderma autoantigen 1 ...
# 41531                                       somatostatin
# 41532                            somatostatin receptor 1
# 41533                            somatostatin receptor 2
# 41534                            somatostatin receptor 3
# 41535                            somatostatin receptor 4
# 41536                            somatostatin receptor 5
# 41537      spermiogenesis specific transcript on the Y 1
# 41538      spermiogenesis specific transcript on the Y 2
# 41539                         ssu-2 homolog (C. elegans)
# 41540  Ssu72 RNA polymerase II CTD phosphatase homolo...
# 41541  synovial sarcoma, X breakpoint 2 interacting p...
# 41542                   synovial sarcoma, X breakpoint 9
# 41543         synovial sarcoma, X member A, breakpoint 1
# 41544         synovial sarcoma, X member B, breakpoint 1
# 41545        synovial sarcoma, X member B, breakpoint 10
# 41546         synovial sarcoma, X member B, breakpoint 2
# 41547         synovial sarcoma, X member B, breakpoint 3
# 41548         synovial sarcoma, X member B, breakpoint 5
# 41549         synovial sarcoma, X member B, breakpoint 6
# ----------------------------------------------------------------------------------------------------
# Total number of genes: 45768, Number of selected genes: 5084

# %% [markdown]
# Filter out genes that were not selected, as well as two categories of cells: low quality cells, and those belonging to ```CR``` and ```Meis2``` subclasses.

# %%
# select genes
genes = slc_gene_df.gene_id.values
gene_indx = [np.where(ref_genes_df.gene_symbol.values == gg)[0][0] for gg in genes]
log1p = logCPM[:, gene_indx]

# remove low quality cells and those belonging to the subclasses 'CR' and 'Meis2'.
mask = (df_anno['cluster']!='Low Quality') & (~df_anno['subclass'].isin(['CR', 'Meis2']))
df_anno = df_anno[mask].reset_index() 
log1p = log1p[mask, :]

print(f'final shape of normalized gene expresion matix: {log1p.shape}')
# Out:
# final shape of normalized gene expresion matix: (22365, 5084)

# %% [markdown]
# Build a data dictionaty for the Smart-seq dataloader.

# %%
# load the tree.csv to obtain colors for t-types on the taxonomies
htree_file = data_path / 'tree.csv'
treeObj = HTree(htree_file=htree_file)
ttypes = treeObj.child[treeObj.isleaf]
colors = treeObj.col[treeObj.isleaf]

# build a data dictionary for the dataloader
data = df_anno[['subclass', 'cluster']].to_dict('list')
data['gene_id'] = genes
data['log1p'] = log1p
data['sample_id'] = df_anno.seq_name.values
data['class_label'] = df_anno['class'].values
data['cluster_color'] = colors[0]*len(data['custer'])

for cluster in df_anno.cluster.unique():
    data['cluster_color']

# %%
data
# Out:
# {'subclass': ['Vip',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Lamp5',
#   'Sst',
#   'Sncg',
#   'Lamp5',
#   'Vip',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Sncg',
#   'Vip',
#   'Serpinf1',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Pvalb',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Vip',
#   'Sst',
#   'Sst',
#   'Lamp5',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Vip',
#   'Sst',
#   'Sst',
#   'Sst',
#   'Lamp5',
#   'Pvalb',
#   'Lamp5',
#   'Pvalb',
#   'Vip',
#   'Sst',
#   'Vip',
#   'Vip',
#   'Sst',
#   'Sst',
#   'Sst',
#   'Vip',
#   'Sst',
#   'Lamp5',
#   'Pvalb',
#   'Sst',
#   'Vip',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Vip',
#   'Lamp5',
#   'Sst',
#   'Vip',
#   'Sst',
#   'Sst',
#   'Pvalb',
#   'Lamp5',
#   'Sst',
#   'Lamp5',
#   'Sncg',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Vip',
#   'Sst',
#   'Pvalb',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6b',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6b',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'Sst',
#   'L6 IT',
#   'L6 IT',
#   'Sst',
#   'Sst',
#   'Vip',
#   'Lamp5',
#   'Vip',
#   'Sst',
#   'Vip',
#   'L2/3 IT',
#   'Lamp5',
#   'Vip',
#   'L2/3 IT',
#   'Sst',
#   'Vip',
#   'Lamp5',
#   'L2/3 IT',
#   'Lamp5',
#   'Vip',
#   'L2/3 IT',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Lamp5',
#   'Vip',
#   'Lamp5',
#   'Vip',
#   'Pvalb',
#   'Sst',
#   'Vip',
#   'Lamp5',
#   'L2/3 IT',
#   'Vip',
#   'Vip',
#   'L2/3 IT',
#   'Pvalb',
#   'Vip',
#   'Pvalb',
#   'Vip',
#   'Vip',
#   'L2/3 IT',
#   'Vip',
#   'Vip',
#   'L2/3 IT',
#   'Vip',
#   'Lamp5',
#   'Sst',
#   'L2/3 IT',
#   'Vip',
#   'Pvalb',
#   'Vip',
#   'Vip',
#   'L2/3 IT',
#   'Lamp5',
#   'Vip',
#   'Lamp5',
#   'Pvalb',
#   'Lamp5',
#   'Pvalb',
#   'Pvalb',
#   'L2/3 IT',
#   'Vip',
#   'L2/3 IT',
#   'Pvalb',
#   'Vip',
#   'Lamp5',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Vip',
#   'Pvalb',
#   'Vip',
#   'Sst',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Sst',
#   'Lamp5',
#   'Sst',
#   'Sst',
#   'Lamp5',
#   'Sst',
#   'Lamp5',
#   'Sst',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Sst',
#   'Vip',
#   'Lamp5',
#   'Vip',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Vip',
#   'Vip',
#   'Lamp5',
#   'Sst',
#   'Lamp5',
#   'Sst',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Lamp5',
#   'Lamp5',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Lamp5',
#   'Sst',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Lamp5',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Lamp5',
#   'Lamp5',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'L2/3 IT',
#   'Lamp5',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Sncg',
#   'Sncg',
#   'Lamp5',
#   'Vip',
#   'Sncg',
#   'Sst',
#   'Sncg',
#   'Sncg',
#   'Sst',
#   'L6 IT',
#   'Lamp5',
#   'Sncg',
#   'Sst',
#   'Sncg',
#   'Lamp5',
#   'Lamp5',
#   'Sncg',
#   'Lamp5',
#   'Pvalb',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Lamp5',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Lamp5',
#   'L2/3 IT',
#   'Lamp5',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Lamp5',
#   'Lamp5',
#   'L2/3 IT',
#   'Sncg',
#   'Lamp5',
#   'L2/3 IT',
#   'Lamp5',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'L5 PT',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Sst',
#   'Sst',
#   'Sst',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Sst',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Sst',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Sst',
#   'Sst',
#   'Sst',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Sst',
#   'Vip',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Sst',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Sst',
#   'Pvalb',
#   'Sst',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Sst',
#   'Lamp5',
#   'Lamp5',
#   'Sst',
#   'Vip',
#   'Lamp5',
#   'Vip',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 CT',
#   'NP',
#   'L6 IT',
#   'Sst',
#   'L6 CT',
#   'L6 CT',
#   'Sst',
#   'Sst',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'Sst',
#   'L6 IT',
#   'L6 CT',
#   'L6 IT',
#   'Lamp5',
#   'L6 IT',
#   'Sst',
#   'Sst',
#   'L6 IT',
#   'Lamp5',
#   'L6 CT',
#   'L6 IT',
#   'L6 IT',
#   'Lamp5',
#   'L5 PT',
#   'NP',
#   'L6 CT',
#   'Sst',
#   'Sst',
#   'L6 IT',
#   'L6 IT',
#   'Sst',
#   'L6 IT',
#   'NP',
#   'L6 CT',
#   'L5 PT',
#   'Sst',
#   'L6 IT',
#   'Sst',
#   'Lamp5',
#   'Sst',
#   'L6 IT',
#   'Lamp5',
#   'Pvalb',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'Vip',
#   'L2/3 IT',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'Lamp5',
#   'L2/3 IT',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'NP',
#   'Sst',
#   'Vip',
#   'L5 IT',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Vip',
#   'NP',
#   'L4',
#   'Vip',
#   'NP',
#   'L5 IT',
#   'Sst',
#   'L6 IT',
#   'L2/3 IT',
#   'L6 IT',
#   'L6 CT',
#   'L6 IT',
#   'L6 IT',
#   'Pvalb',
#   'L6 IT',
#   'Pvalb',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'NP',
#   'NP',
#   'Vip',
#   'L6 CT',
#   'L6 IT',
#   'L6 CT',
#   'Lamp5',
#   'L6 IT',
#   'NP',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'L6 IT',
#   'Sst',
#   'L6 IT',
#   'L6 IT',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Lamp5',
#   'Vip',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Lamp5',
#   'Pvalb',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Sst',
#   'Vip',
#   'Vip',
#   'Vip',
#   'Sst',
#   'Sst',
#   'Serpinf1',
#   'Pvalb',
#   'Sst',
#   'Sst',
#   'Vip',
#   'Vip',
#   'Sst',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Pvalb',
#   'Sst',
#   'Vip',
#   'Pvalb',
#   'Pvalb',
#   'Vip',
#   'Sst',
#   'Pvalb',
#   'Vip',
#   'Lamp5',
#   'Pvalb',
#   'Vip',
#   'Pvalb',
#   'Pvalb',
#   'Lamp5',
#   'Lamp5',
#   'Sst',
#   'Sst',
#   'Vip',
#   'Vip',
#   'Sst',
#   'Sst',
#   'Sncg',
#   'Vip',
#   'Sst',
#   'Sst',
#   'Pvalb',
#   'Lamp5',
#   'Sst',
#   'Sst',
#   'Sst',
#   'Pvalb',
#   'Sncg',
#   'Lamp5',
#   'Lamp5',
#   'Pvalb',
#   'Serpinf1',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Lamp5',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Lamp5',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Sncg',
#   'Lamp5',
#   'Sncg',
#   'Pvalb',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Lamp5',
#   'Vip',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Vip',
#   'L2/3 IT',
#   'Vip',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Vip',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Lamp5',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Lamp5',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'Lamp5',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L2/3 IT',
#   'L4',
#   'L5 IT',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L5 IT',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L5 IT',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L4',
#   'L5 IT',
#   'NP',
#   'NP',
#   'Sst',
#   'Sst',
#   'NP',
#   'NP',
#   'Vip',
#   'Vip',
#   'L5 IT',
#   'Vip',
#   'Vip',
#   'Sst',
#   'NP',
#   'Sst',
#   'NP',
#   'L5 PT',
#   'Vip',
#   'NP',
#   'L6 CT',
#   'L6 IT',
#   'NP',
#   'L5 PT',
#   'NP',
#   'L5 IT',
#   'L5 PT',
#   'L6 IT',
#   'L5 IT',
#   'L5 IT',
#   'Sst',
#   'L5 IT',
#   'NP',
#   'L5 IT',
#   'Vip',
#   'NP',
#   'NP',
#   'Lamp5',
#   'L5 IT',
#   'Sst',
#   'L5 PT',
#   'NP',
#   'Vip',
#   'Sst',
#   'L5 IT',
#   'Vip',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 CT',
#   'L6 IT',
#   'L6 CT',
#   'L6 IT',
#   'L6 IT',
#   'L6 CT',
#   'L6 CT',
#   'L6 IT',
#   ...],
#  'cluster': ['Vip Arhgap36 Hmcn1',
#   'Lamp5 Lsp1',
#   'Lamp5 Lsp1',
#   'Vip Crispld2 Htr2c',
#   'Lamp5 Plch2 Dock5',
#   'Sst Tac1 Tacr3',
#   'Sncg Vip Itih5',
#   'Lamp5 Krt73',
#   'Vip Igfbp6 Car10',
#   'Lamp5 Plch2 Dock5',
#   'Vip Lect1 Oxtr',
#   'Vip Crispld2 Kcne4',
#   'Vip Igfbp6 Pltp',
#   'Vip Crispld2 Htr2c',
#   'Vip Lect1 Oxtr',
#   'Vip Crispld2 Kcne4',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Lsp1',
#   'Lamp5 Lsp1',
#   'Lamp5 Plch2 Dock5',
#   'Sncg Vip Itih5',
#   'Vip Chat Htr1f',
#   'Serpinf1 Aqp5 Vip',
#   'Vip Pygm C1ql1',
#   'Lamp5 Krt73',
#   'Lamp5 Lsp1',
#   'Vip Chat Htr1f',
#   'Vip Pygm C1ql1',
#   'Vip Ptprt Pkp2',
#   'Vip Ptprt Pkp2',
#   'Vip Crispld2 Kcne4',
#   'Pvalb Tpbg',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Fam19a1 Tmem182',
#   'Lamp5 Fam19a1 Tmem182',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Krt73',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Fam19a1 Tmem182',
#   'Lamp5 Krt73',
#   'Lamp5 Fam19a1 Pax6',
#   'Vip Lect1 Oxtr',
#   'Vip Igfbp6 Car10',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Ntn1 Npy2r',
#   'Vip Igfbp6 Pltp',
#   'Lamp5 Lsp1',
#   'Lamp5 Lsp1',
#   'Vip Ptprt Pkp2',
#   'Vip Igfbp6 Pltp',
#   'Sst Tac1 Tacr3',
#   'Pvalb Reln Tac1',
#   'Sst Chrna2 Ptgdr',
#   'Vip Ptprt Pkp2',
#   'Sst Hpse Cbln4',
#   'Sst Hpse Cbln4',
#   'Lamp5 Lsp1',
#   'Sst Chrna2 Glra3',
#   'Pvalb Reln Tac1',
#   'Sst Hpse Sema3c',
#   'Pvalb Reln Tac1',
#   'Sst Chrna2 Ptgdr',
#   'Pvalb Reln Tac1',
#   'Pvalb Reln Tac1',
#   'Pvalb Reln Tac1',
#   'Vip Igfbp4 Mab21l1',
#   'Sst Hpse Sema3c',
#   'Sst Chrna2 Glra3',
#   'Sst Hpse Sema3c',
#   'Lamp5 Lsp1',
#   'Pvalb Reln Tac1',
#   'Lamp5 Lsp1',
#   'Pvalb Vipr2',
#   'Vip Pygm C1ql1',
#   'Sst Hpse Sema3c',
#   'Vip Igfbp4 Mab21l1',
#   'Vip Pygm C1ql1',
#   'Sst Mme Fam114a1',
#   'Sst Rxfp1 Prdm8',
#   'Sst Nr2f2 Necab1',
#   'Vip Arhgap36 Hmcn1',
#   'Sst Nr2f2 Necab1',
#   'Lamp5 Lsp1',
#   'Pvalb Reln Tac1',
#   'Sst Chrna2 Glra3',
#   'Vip Ptprt Pkp2',
#   'Sst Chodl',
#   'Pvalb Calb1 Sst',
#   'Sst Myh8 Etv1 ',
#   'Vip Igfbp4 Mab21l1',
#   'Lamp5 Lsp1',
#   'Sst Mme Fam114a1',
#   'Vip Igfbp4 Mab21l1',
#   'Sst Myh8 Fibin',
#   'Sst Nr2f2 Necab1',
#   'Pvalb Reln Tac1',
#   'Lamp5 Lsp1',
#   'Sst Chrna2 Glra3',
#   'Lamp5 Lsp1',
#   'Sncg Gpr50',
#   'Pvalb Reln Tac1',
#   'Sst Chrna2 Glra3',
#   'Pvalb Gabrg1',
#   'Sst Chrna2 Glra3',
#   'Vip Arhgap36 Hmcn1',
#   'Sst Chrna2 Ptgdr',
#   'Pvalb Reln Tac1',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Nxph2 Wls',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Gpr139',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6b VISp Col8a1 Rprm',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Gpr139',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6b VISp Col8a1 Rxfp1',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Gpr139',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Gpr139',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Krt80 Sla',
#   'L6 CT VISp Gpr139',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Col18a1',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Col23a1 Adamts2',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Col23a1 Adamts2',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Penk Col27a1',
#   'Sst Crh 4930553C11Rik ',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Col23a1 Adamts2',
#   'Sst Crhr2 Efemp1',
#   'Sst Tac1 Tacr3',
#   'Vip Crispld2 Kcne4',
#   'Lamp5 Lsp1',
#   'Vip Crispld2 Htr2c',
#   'Sst Calb2 Pdlim5',
#   'Vip Chat Htr1f',
#   'L2/3 IT VISp Adamts2',
#   'Lamp5 Fam19a1 Tmem182',
#   'Vip Crispld2 Kcne4',
#   'L2/3 IT VISp Rrad',
#   'Sst Tac1 Tacr3',
#   'Vip Pygm C1ql1',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Rrad',
#   'Lamp5 Lsp1',
#   'Vip Chat Htr1f',
#   'L2/3 IT VISp Agmat',
#   'Lamp5 Lsp1',
#   'Vip Chat Htr1f',
#   'Vip Lect1 Oxtr',
#   'Lamp5 Lsp1',
#   'Vip Lect1 Oxtr',
#   'Lamp5 Plch2 Dock5',
#   'Vip Igfbp4 Mab21l1',
#   'Pvalb Tpbg',
#   'Sst Tac1 Htr1d',
#   'Vip Crispld2 Kcne4',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Agmat',
#   'Vip Crispld2 Htr2c',
#   'Vip Crispld2 Htr2c',
#   'L2/3 IT VISp Agmat',
#   'Pvalb Tpbg',
#   'Vip Lect1 Oxtr',
#   'Pvalb Tpbg',
#   'Vip Crispld2 Kcne4',
#   'Vip Crispld2 Htr2c',
#   'L2/3 IT VISp Adamts2',
#   'Vip Chat Htr1f',
#   'Vip Crispld2 Htr2c',
#   'L2/3 IT VISp Rrad',
#   'Vip Crispld2 Kcne4',
#   'Lamp5 Lsp1',
#   'Sst Calb2 Pdlim5',
#   'L2/3 IT VISp Agmat',
#   'Vip Lect1 Oxtr',
#   'Pvalb Tpbg',
#   'Vip Pygm C1ql1',
#   'Vip Chat Htr1f',
#   'L2/3 IT VISp Agmat',
#   'Lamp5 Ntn1 Npy2r',
#   'Vip Lect1 Oxtr',
#   'Lamp5 Lsp1',
#   'Pvalb Tpbg',
#   'Lamp5 Ntn1 Npy2r',
#   'Pvalb Tpbg',
#   'Pvalb Tpbg',
#   'L2/3 IT VISp Rrad',
#   'Vip Crispld2 Htr2c',
#   'L2/3 IT VISp Agmat',
#   'Pvalb Tpbg',
#   'Vip Pygm C1ql1',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Rrad',
#   'L2/3 IT VISp Rrad',
#   'Vip Crispld2 Htr2c',
#   'Pvalb Tpbg',
#   'Vip Rspo1 Itga4',
#   'Sst Rxfp1 Eya1',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Col23a1 Adamts2',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Col23a1 Adamts2',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Col23a1 Adamts2',
#   'L6 IT VISp Col23a1 Adamts2',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Col23a1 Adamts2',
#   'L6 IT VISp Col23a1 Adamts2',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Penk Col27a1',
#   'Lamp5 Lsp1',
#   'Lamp5 Lhx6',
#   'Lamp5 Lhx6',
#   'Sst Chodl',
#   'Lamp5 Ntn1 Npy2r',
#   'Sst Chodl',
#   'Sst Tac1 Htr1d',
#   'Lamp5 Lhx6',
#   'Sst Tac1 Htr1d',
#   'Lamp5 Lsp1',
#   'Sst Tac1 Htr1d',
#   'Lamp5 Lsp1',
#   'Lamp5 Lsp1',
#   'Vip Igfbp6 Pltp',
#   'Vip Igfbp6 Pltp',
#   'Sst Tac1 Tacr3',
#   'Vip Rspo4 Rxfp1 Chat',
#   'Lamp5 Lhx6',
#   'Vip Rspo4 Rxfp1 Chat',
#   'Sst Chodl',
#   'Pvalb Tpbg',
#   'Sst Chodl',
#   'Vip Igfbp6 Pltp',
#   'Vip Ptprt Pkp2',
#   'Lamp5 Lsp1',
#   'Sst Tac1 Htr1d',
#   'Lamp5 Lsp1',
#   'Sst Tac1 Htr1d',
#   'Vip Ptprt Pkp2',
#   'Lamp5 Lhx6',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Rrad',
#   'L2/3 IT VISp Agmat',
#   'Lamp5 Lsp1',
#   'Lamp5 Plch2 Dock5',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Rrad',
#   'Lamp5 Lsp1',
#   'Sst Hpse Cbln4',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Rrad',
#   'L2/3 IT VISp Agmat',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Krt73',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'Lamp5 Lsp1',
#   'Lamp5 Fam19a1 Pax6',
#   'Lamp5 Fam19a1 Pax6',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Rrad',
#   'Lamp5 Krt73',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'Sncg Slc17a8',
#   'Sncg Vip Itih5',
#   'Lamp5 Lsp1',
#   'Vip Lmo1 Fam159b',
#   'Sncg Slc17a8',
#   'Sst Esm1',
#   'Sncg Gpr50',
#   'Sncg Vip Itih5',
#   'Sst Mme Fam114a1',
#   'L6 IT VISp Penk Col27a1',
#   'Lamp5 Lsp1',
#   'Sncg Slc17a8',
#   'Sst Crhr2 Efemp1',
#   'Sncg Slc17a8',
#   'Lamp5 Lsp1',
#   'Lamp5 Lhx6',
#   'Sncg Slc17a8',
#   'Lamp5 Lsp1',
#   'Pvalb Calb1 Sst',
#   'Lamp5 Lsp1',
#   'Lamp5 Lsp1',
#   'Lamp5 Lsp1',
#   'Lamp5 Fam19a1 Pax6',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Rrad',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Rrad',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'Lamp5 Lsp1',
#   'Lamp5 Krt73',
#   'L2/3 IT VISp Agmat',
#   'Sncg Slc17a8',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Agmat',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Adamts2',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Adamts2',
#   'Pvalb Reln Tac1',
#   'Pvalb Gpr149 Islr',
#   'Pvalb Gpr149 Islr',
#   'Pvalb Gpr149 Islr',
#   'Pvalb Gpr149 Islr',
#   'Pvalb Reln Tac1',
#   'Pvalb Gpr149 Islr',
#   'Sst Mme Fam114a1',
#   'Pvalb Reln Tac1',
#   'L5 PT VISp Krt80',
#   'Pvalb Gpr149 Islr',
#   'Pvalb Reln Tac1',
#   'Pvalb Reln Tac1',
#   'Pvalb Gpr149 Islr',
#   'Sst Hpse Sema3c',
#   'Pvalb Gabrg1',
#   'Pvalb Reln Tac1',
#   'Pvalb Reln Tac1',
#   'Pvalb Reln Tac1',
#   'Pvalb Reln Tac1',
#   'Pvalb Gpr149 Islr',
#   'Pvalb Reln Tac1',
#   'Sst Tac2 Tacstd2',
#   'Sst Tac2 Tacstd2',
#   'Pvalb Th Sst',
#   'Pvalb Akr1c18 Ntf3',
#   'Sst Tac2 Tacstd2',
#   'Sst Rxfp1 Prdm8',
#   'Pvalb Gpr149 Islr',
#   'Pvalb Th Sst',
#   'Sst Crhr2 Efemp1',
#   'Pvalb Reln Tac1',
#   'Sst Rxfp1 Prdm8',
#   'Pvalb Akr1c18 Ntf3',
#   'Pvalb Akr1c18 Ntf3',
#   'Pvalb Th Sst',
#   'Sst Crhr2 Efemp1',
#   'Pvalb Reln Tac1',
#   'Pvalb Akr1c18 Ntf3',
#   'Pvalb Akr1c18 Ntf3',
#   'Pvalb Reln Tac1',
#   'Sst Crh 4930553C11Rik ',
#   'Sst Rxfp1 Eya1',
#   'Pvalb Reln Tac1',
#   'Sst Rxfp1 Eya1',
#   'Pvalb Akr1c18 Ntf3',
#   'Sst Rxfp1 Eya1',
#   'Pvalb Akr1c18 Ntf3',
#   'Sst Rxfp1 Eya1',
#   'Sst Rxfp1 Prdm8',
#   'Sst Rxfp1 Prdm8',
#   'Sst Rxfp1 Eya1',
#   'Sst Rxfp1 Prdm8',
#   'Pvalb Sema3e Kank4',
#   'Pvalb Reln Tac1',
#   'Sst Crh 4930553C11Rik ',
#   'Sst Rxfp1 Prdm8',
#   'Pvalb Calb1 Sst',
#   'Pvalb Th Sst',
#   'Sst Rxfp1 Prdm8',
#   'Sst Rxfp1 Eya1',
#   'Sst Crh 4930553C11Rik ',
#   'Pvalb Gpr149 Islr',
#   'Pvalb Reln Tac1',
#   'Pvalb Reln Tac1',
#   'Pvalb Reln Tac1',
#   'Sst Mme Fam114a1',
#   'Pvalb Reln Tac1',
#   'Pvalb Gpr149 Islr',
#   'Sst Tac2 Tacstd2',
#   'Pvalb Reln Tac1',
#   'Pvalb Gpr149 Islr',
#   'Sst Rxfp1 Prdm8',
#   'Pvalb Reln Tac1',
#   'Pvalb Reln Tac1',
#   'Sst Rxfp1 Prdm8',
#   'Sst Rxfp1 Prdm8',
#   'Sst Mme Fam114a1',
#   'Pvalb Reln Tac1',
#   'Pvalb Calb1 Sst',
#   'Sst Mme Fam114a1',
#   'Sst Tac2 Tacstd2',
#   'Pvalb Calb1 Sst',
#   'Sst Tac2 Tacstd2',
#   'Pvalb Reln Tac1',
#   'Pvalb Reln Tac1',
#   'Sst Tac2 Tacstd2',
#   'Sst Tac2 Tacstd2',
#   'Pvalb Reln Tac1',
#   'Sst Chrna2 Ptgdr',
#   'Sst Rxfp1 Prdm8',
#   'Pvalb Reln Tac1',
#   'Sst Rxfp1 Prdm8',
#   'Pvalb Reln Tac1',
#   'Pvalb Reln Tac1',
#   'Pvalb Th Sst',
#   'Pvalb Sema3e Kank4',
#   'Pvalb Calb1 Sst',
#   'Pvalb Th Sst',
#   'Sst Esm1',
#   'Pvalb Calb1 Sst',
#   'Sst Rxfp1 Prdm8',
#   'Pvalb Akr1c18 Ntf3',
#   'Pvalb Th Sst',
#   'Pvalb Akr1c18 Ntf3',
#   'Pvalb Th Sst',
#   'Sst Rxfp1 Prdm8',
#   'Pvalb Gabrg1',
#   'Pvalb Th Sst',
#   'Pvalb Th Sst',
#   'Sst Rxfp1 Eya1',
#   'Pvalb Th Sst',
#   'Sst Rxfp1 Prdm8',
#   'Pvalb Reln Tac1',
#   'Pvalb Gabrg1',
#   'Sst Rxfp1 Prdm8',
#   'Sst Rxfp1 Prdm8',
#   'Sst Crh 4930553C11Rik ',
#   'Sst Crhr2 Efemp1',
#   'Sst Esm1',
#   'Pvalb Reln Tac1',
#   'Pvalb Gabrg1',
#   'Pvalb Sema3e Kank4',
#   'Pvalb Reln Tac1',
#   'Pvalb Akr1c18 Ntf3',
#   'Pvalb Reln Tac1',
#   'Pvalb Tpbg',
#   'Vip Col15a1 Pde1a',
#   'Vip Pygm C1ql1',
#   'Vip Pygm C1ql1',
#   'Sst Tac1 Tacr3',
#   'Vip Pygm C1ql1',
#   'Lamp5 Ntn1 Npy2r',
#   'Vip Igfbp6 Car10',
#   'Vip Chat Htr1f',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Plch2 Dock5',
#   'Pvalb Reln Itm2a',
#   'Pvalb Tpbg',
#   'Pvalb Tpbg',
#   'Pvalb Tpbg',
#   'Sst Calb2 Pdlim5',
#   'Sst Tac1 Tacr3',
#   'Vip Pygm C1ql1',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Lsp1',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Fam19a1 Tmem182',
#   'Vip Chat Htr1f',
#   'Vip Chat Htr1f',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Lsp1',
#   'Vip Chat Htr1f',
#   'Sst Tac1 Tacr3',
#   'Pvalb Tpbg',
#   'Sst Tac1 Tacr3',
#   'Vip Chat Htr1f',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Plch2 Dock5',
#   'Sst Calb2 Pdlim5',
#   'Lamp5 Lsp1',
#   'Lamp5 Plch2 Dock5',
#   'Sst Chodl',
#   'Vip Pygm C1ql1',
#   'Lamp5 Plch2 Dock5',
#   'Vip Chat Htr1f',
#   'L6 IT VISp Col23a1 Adamts2',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Col23a1 Adamts2',
#   'L6 CT VISp Krt80 Sla',
#   'L5 NP ALM Trhr Nefl',
#   'L6 IT VISp Penk Fst',
#   'Sst Esm1',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Krt80 Sla',
#   'Sst Tac2 Myh4',
#   'Sst Esm1',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Col18a1',
#   'L6 IT VISp Penk Fst',
#   'Sst Hpse Sema3c',
#   'L6 IT VISp Penk Fst',
#   'L6 CT ALM Nxph2 Sla',
#   'L6 IT VISp Col23a1 Adamts2',
#   'Lamp5 Lhx6',
#   'L6 IT VISp Penk Fst',
#   'Sst Calb2 Pdlim5',
#   'Sst Chrna2 Glra3',
#   'L6 IT VISp Col18a1',
#   'Lamp5 Lsp1',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Col18a1',
#   'Lamp5 Lsp1',
#   'L5 PT VISp Chrna6',
#   'L5 NP VISp Trhr Cpne7',
#   'L6 CT VISp Gpr139',
#   'Sst Calb2 Pdlim5',
#   'Sst Crhr2 Efemp1',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Penk Col27a1',
#   'Sst Myh8 Etv1 ',
#   'L6 IT VISp Penk Col27a1',
#   'L5 NP VISp Trhr Cpne7',
#   'L6 CT VISp Ctxn3 Sla',
#   'L5 PT VISp C1ql2 Cdh13',
#   'Sst Myh8 Fibin',
#   'L6 IT VISp Col23a1 Adamts2',
#   'Sst Chrna2 Glra3',
#   'Lamp5 Lsp1',
#   'Sst Chrna2 Glra3',
#   'L6 IT VISp Col23a1 Adamts2',
#   'Lamp5 Lsp1',
#   'Pvalb Tpbg',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'Vip Chat Htr1f',
#   'L2/3 IT VISp Agmat',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Agmat',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L5 NP VISp Trhr Cpne7',
#   'Sst Hpse Sema3c',
#   'Vip Pygm C1ql1',
#   'L5 IT VISp Hsd11b1 Endou',
#   'Vip Pygm C1ql1',
#   'Vip Chat Htr1f',
#   'Vip Ptprt Pkp2',
#   'Vip Pygm C1ql1',
#   'Vip Ptprt Pkp2',
#   'L5 NP VISp Trhr Met',
#   'L4 IT VISp Rspo1',
#   'Vip Pygm C1ql1',
#   'L5 NP VISp Trhr Cpne7',
#   'L5 IT VISp Batf3',
#   'Sst Hpse Sema3c',
#   'L6 IT VISp Car3',
#   'L2/3 IT VISp Agmat',
#   'L6 IT VISp Penk Col27a1',
#   'L6 CT VISp Nxph2 Wls',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Penk Fst',
#   'Pvalb Gabrg1',
#   'L6 IT VISp Penk Col27a1',
#   'Pvalb Gabrg1',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Car3',
#   'L6 IT VISp Penk Col27a1',
#   'L5 NP VISp Trhr Cpne7',
#   'L5 NP VISp Trhr Met',
#   'Vip Igfbp4 Mab21l1',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 IT VISp Penk Col27a1',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'Lamp5 Lsp1',
#   'L6 IT VISp Col23a1 Adamts2',
#   'L5 NP VISp Trhr Cpne7',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Col18a1',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Penk Col27a1',
#   'L6 IT VISp Col23a1 Adamts2',
#   'Sst Chodl',
#   'L6 IT VISp Penk Fst',
#   'L6 IT VISp Penk Col27a1',
#   'Vip Ptprt Pkp2',
#   'Vip Crispld2 Kcne4',
#   'Vip Rspo4 Rxfp1 Chat',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Fam19a1 Tmem182',
#   'Lamp5 Lsp1',
#   'Lamp5 Fam19a1 Pax6',
#   'Lamp5 Lsp1',
#   'Vip Pygm C1ql1',
#   'Lamp5 Lsp1',
#   'Vip Igfbp6 Pltp',
#   'Vip Pygm C1ql1',
#   'Vip Chat Htr1f',
#   'Vip Ptprt Pkp2',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Lsp1',
#   'Lamp5 Fam19a1 Pax6',
#   'Vip Chat Htr1f',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Plch2 Dock5',
#   'Vip Crispld2 Htr2c',
#   'Vip Igfbp6 Pltp',
#   'Vip Chat Htr1f',
#   'Lamp5 Lsp1',
#   'Vip Chat Htr1f',
#   'Lamp5 Ntn1 Npy2r',
#   'Vip Igfbp6 Car10',
#   'Vip Crispld2 Kcne4',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Lsp1',
#   'Vip Ptprt Pkp2',
#   'Vip Crispld2 Kcne4',
#   'Vip Igfbp6 Pltp',
#   'Vip Igfbp4 Mab21l1',
#   'Vip Gpc3 Slc18a3',
#   'Lamp5 Lsp1',
#   'Pvalb Reln Itm2a',
#   'Vip Igfbp6 Pltp',
#   'Vip Ptprt Pkp2',
#   'Vip Igfbp4 Mab21l1',
#   'Lamp5 Lsp1',
#   'Lamp5 Lsp1',
#   'Vip Lmo1 Myl1',
#   'Vip Igfbp6 Pltp',
#   'Vip Ptprt Pkp2',
#   'Vip Igfbp6 Pltp',
#   'Vip Arhgap36 Hmcn1',
#   'Lamp5 Ntn1 Npy2r',
#   'Vip Arhgap36 Hmcn1',
#   'Vip Igfbp6 Pltp',
#   'Sst Hpse Sema3c',
#   'Vip Ptprt Pkp2',
#   'Vip Igfbp6 Pltp',
#   'Vip Chat Htr1f',
#   'Sst Chrna2 Glra3',
#   'Sst Hpse Sema3c',
#   'Serpinf1 Aqp5 Vip',
#   'Pvalb Tpbg',
#   'Sst Rxfp1 Eya1',
#   'Sst Myh8 Fibin',
#   'Vip Ptprt Pkp2',
#   'Vip Arhgap36 Hmcn1',
#   'Sst Chrna2 Ptgdr',
#   'Pvalb Reln Tac1',
#   'Pvalb Gabrg1',
#   'Pvalb Tpbg',
#   'Pvalb Reln Tac1',
#   'Sst Chrna2 Ptgdr',
#   'Vip Arhgap36 Hmcn1',
#   'Pvalb Calb1 Sst',
#   'Pvalb Reln Tac1',
#   'Vip Igfbp6 Pltp',
#   'Sst Rxfp1 Prdm8',
#   'Pvalb Reln Tac1',
#   'Vip Gpc3 Slc18a3',
#   'Lamp5 Lsp1',
#   'Pvalb Th Sst',
#   'Vip Gpc3 Slc18a3',
#   'Pvalb Reln Tac1',
#   'Pvalb Reln Tac1',
#   'Lamp5 Lsp1',
#   'Lamp5 Lsp1',
#   'Sst Nr2f2 Necab1',
#   'Sst Myh8 Etv1 ',
#   'Vip Gpc3 Slc18a3',
#   'Vip Arhgap36 Hmcn1',
#   'Sst Rxfp1 Eya1',
#   'Sst Chrna2 Glra3',
#   'Sncg Vip Itih5',
#   'Vip Gpc3 Slc18a3',
#   'Sst Tac2 Tacstd2',
#   'Sst Esm1',
#   'Pvalb Th Sst',
#   'Lamp5 Lhx6',
#   'Sst Nr2f2 Necab1',
#   'Sst Esm1',
#   'Sst Chodl',
#   'Pvalb Th Sst',
#   'Sncg Slc17a8',
#   'Lamp5 Lsp1',
#   'Lamp5 Lhx6',
#   'Pvalb Th Sst',
#   'Serpinf1 Clrn1',
#   'Lamp5 Lsp1',
#   'Lamp5 Plch2 Dock5',
#   'Vip Chat Htr1f',
#   'Lamp5 Lsp1',
#   'Vip Crispld2 Htr2c',
#   'Lamp5 Lsp1',
#   'Lamp5 Plch2 Dock5',
#   'Vip Igfbp4 Mab21l1',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Ntn1 Npy2r',
#   'Vip Pygm C1ql1',
#   'Lamp5 Ntn1 Npy2r',
#   'Vip Crispld2 Htr2c',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Lsp1',
#   'Vip Igfbp4 Mab21l1',
#   'Vip Col15a1 Pde1a',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Lsp1',
#   'Lamp5 Lsp1',
#   'Lamp5 Lsp1',
#   'Sncg Vip Nptx2',
#   'Lamp5 Lsp1',
#   'Sncg Vip Nptx2',
#   'Pvalb Vipr2',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Plch2 Dock5',
#   'Lamp5 Lsp1',
#   'Lamp5 Ntn1 Npy2r',
#   'Vip Crispld2 Htr2c',
#   'Lamp5 Krt73',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Lsp1',
#   'Lamp5 Ntn1 Npy2r',
#   'Lamp5 Plch2 Dock5',
#   'Vip Igfbp6 Car10',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'Vip Pygm C1ql1',
#   'L2/3 IT VISp Adamts2',
#   'Vip Lmo1 Myl1',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Adamts2',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'Vip Chat Htr1f',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Adamts2',
#   'L2/3 IT VISp Adamts2',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Adamts2',
#   'Lamp5 Fam19a1 Tmem182',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Adamts2',
#   'L2/3 IT VISp Agmat',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Adamts2',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'Lamp5 Lsp1',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Rrad',
#   'L2/3 IT VISp Adamts2',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Rrad',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L2/3 IT VISp Agmat',
#   'L4 IT VISp Rspo1',
#   'L5 IT VISp Hsd11b1 Endou',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L5 IT VISp Hsd11b1 Endou',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L5 IT VISp Hsd11b1 Endou',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L4 IT VISp Rspo1',
#   'L5 IT VISp Batf3',
#   'L5 NP VISp Trhr Cpne7',
#   'L5 NP VISp Trhr Cpne7',
#   'Sst Nr2f2 Necab1',
#   'Sst Calb2 Pdlim5',
#   'L5 NP VISp Trhr Cpne7',
#   'L5 NP VISp Trhr Cpne7',
#   'Vip Ptprt Pkp2',
#   'Vip Gpc3 Slc18a3',
#   'L5 IT VISp Batf3',
#   'Vip Crispld2 Htr2c',
#   'Vip Gpc3 Slc18a3',
#   'Sst Chrna2 Glra3',
#   'L5 NP VISp Trhr Cpne7',
#   'Sst Chrna2 Ptgdr',
#   'L5 NP ALM Trhr Nefl',
#   'L5 PT VISp C1ql2 Ptgfr',
#   'Vip Ptprt Pkp2',
#   'L5 NP VISp Trhr Cpne7',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 IT VISp Penk Col27a1',
#   'L5 NP VISp Trhr Cpne7',
#   'L5 PT VISp C1ql2 Ptgfr',
#   'L5 NP VISp Trhr Cpne7',
#   'L5 IT VISp Col27a1',
#   'L5 PT VISp Chrna6',
#   'L6 IT VISp Penk Col27a1',
#   'L5 IT VISp Hsd11b1 Endou',
#   'L5 IT VISp Col27a1',
#   'Sst Calb2 Pdlim5',
#   'L5 IT VISp Col27a1',
#   'L5 NP VISp Trhr Cpne7',
#   'L5 IT VISp Batf3',
#   'Vip Ptprt Pkp2',
#   'L5 NP VISp Trhr Cpne7',
#   'L5 NP VISp Trhr Met',
#   'Lamp5 Lsp1',
#   'L5 IT VISp Batf3',
#   'Sst Calb2 Pdlim5',
#   'L5 PT VISp Krt80',
#   'L5 NP VISp Trhr Cpne7',
#   'Vip Lmo1 Fam159b',
#   'Sst Chrna2 Glra3',
#   'L5 IT VISp Hsd11b1 Endou',
#   'Vip Chat Htr1f',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 CT VISp Krt80 Sla',
#   'L6 IT VISp Penk Col27a1',
#   'L6 CT VISp Ctxn3 Sla',
#   'L6 IT VISp Col18a1',
#   'L6 IT VISp Col18a1',
#   'L6 CT VISp Ctxn3 Brinp3',
#   'L6 CT VISp Krt80 Sla',
#   'L6 IT VISp Col23a1 Adamts2',
#   ...],
#  'gene_id': array(['0610007P14Rik', '0610009B22Rik', '0610010F05Rik', ..., 'Zwint',
#         'Zyg11b', 'l7Rn6'], dtype=object),
#  'log1p': array([[3.84258223, 4.40539198, 0.        , ..., 8.12184603, 3.83011802,
#          4.70755495],
#         [4.16454502, 4.52873471, 4.56208788, ..., 8.57614595, 2.7512759 ,
#          4.54555034],
#         [3.82509693, 3.56268307, 3.93922807, ..., 8.19817952, 4.35773081,
#          4.35773081],
#         ...,
#         [5.20345657, 5.52158507, 4.48315244, ..., 7.80344409, 3.39382126,
#          5.56973714],
#         [5.11344867, 3.68484865, 4.35635004, ..., 6.02441697, 3.86297794,
#          0.        ],
#         [4.50345362, 4.83760608, 4.30063499, ..., 7.44488013, 5.51608411,
#          5.38527466]]),
#  'sample_id': array(['LS-15006_S09_E1-50', 'LS-15006_S10_E1-50', 'LS-15006_S11_E1-50',
#         ..., 'SM-DAIHI_S70_E1-50', 'SM-DAIHI_S71_E1-50',
#         'SM-DAIHI_S72_E1-50'], dtype=object),
#  'class_label': array(['GABAergic', 'GABAergic', 'GABAergic', ..., 'Glutamatergic',
#         'Glutamatergic', 'Glutamatergic'], dtype=object)}

# %%
treeObj.col[treeObj.isleaf].shape
# Out:
# (133,)
